# %% [markdown]
# # This is DAY1 in KIET: Practice Python
#
#
#
#
#
# ## Sub Heading1
# ## Sub Heading2
# ## Sub Heading3
# ## Sub Heading4
# ## Sub Heading5

# %% [markdown]
# - abhi
# - iliyas
# - sai
# - venkie
# - shankar

# %%
print("Hello KIET, Welcome to AAI:Practical Implementation")
# Out:
# Hello KIET, Welcome to AAI:Practical Implementation

# %%
print("Happy to train you 🎉")
# Out:
# Happy to train you 🎉
